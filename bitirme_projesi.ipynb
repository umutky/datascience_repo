# %%
magaza_adi = ['KÜÇÜKYALI HILLTOWN MACROCENTER',
'PIAZZA MALTEPE MACROCENTER',
'ASKERİ LOJ. KÜÇÜKYALI İST M',
'IRMAKLAR SK MALTEPE İSTANBUL M',
'NISH ADALAR MALTEPE MM MİGROS',
'GİRNE MAH MALTEPE İST MİNİGROS',
'GÜLYOLU MALTEPE İST MİNİGROS',
'KADİR HAS CD. İST MİNİGROS',
'MENEKŞELİ SK. MALTEPE MİNİGROS',
'MALTEPE YALI CAD..MACROKIOSK',
'RİTİM AVM MALTEPE İSTANBUL MM',
'TUGAYYOLU MALTEPE MM MİGROS',
'OFİSPARK MALTEPE MM MİGROS',
'MESA İSTANBUL MALTEPE MM',
'NARCITY MALTEPE İSTANBUL M',
'BAĞLARBAŞI MALTEPE M MİGROS',
'EVİNPARK MALTEPE M MİGROS',
'MJET MALTEPE YALI MAHALLESİ',
'MJET ZÜMRÜTEVLER MALTEPE İST',
'MJET FINDIKLI MALTEPE',
'MJET NİSH AVLU MALTEPE',
'MJET FİRUZ ÇIKMAZI MALTEPE İST',
'MJET ALTINTEPE İSTANBUL',
'MJET KÜÇÜKYALI 63',
'MJET KÜÇÜKYALI PO İSTASYON',
'MJET İDEALTEPE CADDE İSTANBUL',
'MJET ORHANGAZİ CADDESİ MALTEPE',
'MJET GİRNE MAHALLESİ MALTEPE',
'MJET MALTEPE NEVADA',
'MJET NİSH ADALAR',
'MJET FUAYE PO',
'ALTINTEPE M MİGROS',
'FUAYE İSTANBUL MMM MİGROS',
'KÜÇÜKYALI İSTANBUL M MİGROS',
'SÜREYYA PAŞA MMM MİGROS']

koordinatlar = [[40.952686658232295, 29.121208035372987],
[40.92128470164432, 29.165538126387283],
[40.95468563836487, 29.123821421100054],
[40.94383179920128, 29.136009205869826],
[40.94870794538319, 29.160562955773933],
[40.938631772931316, 29.13806174161115],
[40.92802770391542, 29.1389340834801],
[40.9447965345502, 29.117321250036145],
[40.925836713623404, 29.130363152522857],
[40.918000068975864, 29.136015788077426],
[40.92181694509281, 29.15815086660945],
[40.917428404776196, 29.159940216855254],
[40.93799450691945, 29.135251567008822],
[40.93191548340477, 29.127265637593823],
[40.95487209668625, 29.167318865563793],
[40.92381052092096, 29.13449886571158],
[40.936596283607656, 29.132266250105125],
[40.9185294335012, 29.133939204295885],
[40.93742235769825, 29.141501285893472],
[40.969187532857674, 29.12345584823173],
[40.944371636564995, 29.15901126487112],
[40.94320780411222, 29.144398997022627],
[40.9527089740197, 29.097007129763984],
[40.94923165010923, 29.10590466959333],
[40.94791709562063, 29.10654747189149],
[40.938185139926404, 29.11945265477902],
[40.92147188412524, 29.148882922715064],
[40.94104461467149, 29.14056061182688],
[40.936220953009226, 29.125270928031444],
[40.9442638911282, 29.159328090876457],
[40.95051052069334, 29.162685408802766],
[40.95343875225428, 29.10032154626482],
[40.950149181140475, 29.165442147825367],
[40.944769195810856, 29.112264258198973],
[40.925774074670755, 29.124492347070344]]

# %%
magaza_koordinatlar = {'magaza_adi' : magaza_adi, 'koordinat' : koordinatlar}

# %%
import folium

# Maltepe'nin koordinatları
maltepe_koordinat = [40.9654, 29.0805]

# Mağaza koordinatları
magaza_koordinatlar = [
    {"name": "KÜÇÜKYALI HILLTOWN MACROCENTER", "koordinat": [40.952686658232295, 29.121208035372987]},
    {"name": "PIAZZA MALTEPE MACROCENTER", "koordinat": [40.92128470164432, 29.165538126387283]},
    {"name": "ASKERİ LOJ. KÜÇÜKYALI İST M", "koordinat": [40.95468563836487, 29.123821421100054]},
    {"name": "IRMAKLAR SK MALTEPE İSTANBUL M", "koordinat": [40.94383179920128, 29.136009205869826]},
    {"name": "NISH ADALAR MALTEPE MM MİGROS", "koordinat": [40.94870794538319, 29.160562955773933]},
    {"name": "GİRNE MAH MALTEPE İST MİNİGROS", "koordinat": [40.938631772931316, 29.13806174161115]},
    {"name": "GÜLYOLU MALTEPE İST MİNİGROS", "koordinat": [40.92802770391542, 29.1389340834801]},
    {"name": "KADİR HAS CD. İST MİNİGROS", "koordinat": [40.9447965345502, 29.117321250036145]},
    {"name": "MENEKŞELİ SK. MALTEPE MİNİGROS", "koordinat": [40.925836713623404, 29.130363152522857]},
    {"name": "MALTEPE YALI CAD..MACROKIOSK", "koordinat": [40.918000068975864, 29.136015788077426]},
    {"name": "RİTİM AVM MALTEPE İSTANBUL MM", "koordinat": [40.92181694509281, 29.15815086660945]},
    {"name": "TUGAYYOLU MALTEPE MM MİGROS", "koordinat": [40.917428404776196, 29.159940216855254]},
    {"name": "OFİSPARK MALTEPE MM MİGROS", 'koordinat': [40.93799450691945, 29.135251567008822]},
    {"name": "MESA İSTANBUL MALTEPE MM", "koordinat": [40.93191548340477, 29.127265637593823]},
    {"name": "NARCITY MALTEPE İSTANBUL M", "koordinat": [40.95487209668625, 29.167318865563793]},
    {"name": "BAĞLARBAŞI MALTEPE M MİGROS", "koordinat": [40.92381052092096, 29.13449886571158]},
    {"name": "EVİNPARK MALTEPE M MİGROS", "koordinat": [40.936596283607656, 29.132266250105125]},
    {"name": "MJET MALTEPE YALI MAHALLESİ", "koordinat": [40.9185294335012, 29.133939204295885]},
    {"name": "MJET ZÜMRÜTEVLER MALTEPE İST", "koordinat": [40.93742235769825, 29.141501285893472]},
    {"name": "MJET FINDIKLI MALTEPE", "koordinat": [40.969187532857674, 29.12345584823173]},
    {"name": "MJET NİSH AVLU MALTEPE", "koordinat": [40.944371636564995, 29.15901126487112]},
    {"name": "MJET FİRUZ ÇIKMAZI MALTEPE İST", "koordinat": [40.94320780411222, 29.144398997022627]},
    {"name": "MJET ALTINTEPE İSTANBUL", "koordinat": [40.9527089740197, 29.097007129763984]},
    {"name": "MJET KÜÇÜKYALI 63", "koordinat": [40.94923165010923, 29.10590466959333]},
    {"name": "MJET KÜÇÜKYALI PO İSTASYON", "koordinat": [40.94791709562063, 29.10654747189149]},
    {"name": "MJET İDEALTEPE CADDE İSTANBUL", "koordinat": [40.938185139926404, 29.11945265477902]},
    {"name": "MJET ORHANGAZİ CADDESİ MALTEPE", "koordinat": [40.92147188412524, 29.148882922715064]},
    {"name": "MJET GİRNE MAHALLESİ MALTEPE", "koordinat": [40.94104461467149, 29.14056061182688]},
    {"name": "MJET MALTEPE NEVADA", "koordinat": [40.936220953009226, 29.125270928031444]},
    {"name": "MJET NİSH ADALAR", "koordinat": [40.9442638911282, 29.159328090876457]},
    {"name": "MJET FUAYE PO", "koordinat": [40.95051052069334, 29.162685408802766]},
    
    
    {"name": "ALTINTEPE M MİGROS", "koordinat": [40.95343875225428, 29.10032154626482]},
    {"name": "FUAYE İSTANBUL MMM MİGROS", "koordinat": [40.950149181140475, 29.165442147825367]},
    {"name": "KÜÇÜKYALI İSTANBUL M MİGROS", "koordinat": [40.944769195810856, 29.112264258198973]},
    {"name": "SÜREYYA PAŞA MMM MİGROS", "koordinat": [40.925774074670755, 29.124492347070344]},
]

# Haritayı oluştur
harita = folium.Map(location=maltepe_koordinat, zoom_start=14, tiles='Stamen Terrain')

# Mağazaları haritaya ekleyin
for magaza in magaza_koordinatlar:
    folium.Marker(
        location=magaza["koordinat"],
        popup=magaza["name"],
        icon=folium.Icon(color='blue')
    ).add_to(harita)

# Haritayı göster
harita
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
